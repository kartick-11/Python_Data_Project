# %%
#Importing Libraries
import pandas as pd
from datasets import load_dataset
import matplotlib.pyplot as plt

#Loading the dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df.head()
# Out:
#         job_title_short                                          job_title  \
# 0  Senior Data Engineer  Senior Clinical Data Engineer / Principal Clin...
# 1          Data Analyst                                       Data Analyst
# 2         Data Engineer  Data Engineer/Scientist/Analyst, Mid or Senior...
# 3         Data Engineer  LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...
# 4         Data Engineer                             Data Engineer- Sr Jobs
#
#                    job_location             job_via job_schedule_type  \
# 0                 Watertown, CT     via Work Nearby         Full-time
# 1  Guadalajara, Jalisco, Mexico    via BeBee México         Full-time
# 2               Berlin, Germany        via LinkedIn         Full-time
# 3               San Antonio, TX   via Diversity.com         Full-time
# 4                Washington, DC  via Clearance Jobs         Full-time
#
#    job_work_from_home       search_location     job_posted_date  \
# 0               False  Texas, United States 2023-06-16 13:44:15
# 1               False                Mexico 2023-01-14 13:18:07
# 2               False               Germany 2023-10-10 13:14:55
# 3               False  Texas, United States 2023-07-04 13:01:41
# 4               False                 Sudan 2023-08-07 14:29:36
#
#    job_no_degree_mention  job_health_insurance    job_country salary_rate  \
# 0                  False                 False  United States        None
# 1                  False                 False         Mexico        None
# 2                  False                 False        Germany        None
# 3                   True                 False  United States        None
# 4                  False                 False          Sudan        None
#
#    salary_year_avg  salary_hour_avg                  company_name  \
# 0              NaN              NaN          Boehringer Ingelheim
# 1              NaN              NaN    Hewlett Packard Enterprise
# 2              NaN              NaN      ALPHA Augmented Services
# 3              NaN              NaN  Southwest Research Institute
# 4              NaN              NaN               Kristina Daniel
#
#                                           job_skills  \
# 0                                               None
# 1  ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2  ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3  ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4  ['bash', 'python', 'oracle', 'aws', 'ansible',...
#
#                                      job_type_skills
# 0                                               None
# 1  {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2  {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3  {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4  {'cloud': ['oracle', 'aws'], 'other': ['ansibl...

# %%
df.tail()
# Out:
#           job_title_short                                          job_title  \
# 785736  Software Engineer                                    DevOps Engineer
# 785737       Data Analyst                                   CRM Data Analyst
# 785738   Business Analyst                     Commercial Analyst - Start Now
# 785739      Data Engineer  Principal Associate, Data Engineer (Remote-Eli...
# 785740  Software Engineer                                 AWS System Analyst
#
#                                job_location                    job_via  \
# 785736                            Singapura        melalui Trabajo.org
# 785737                   Bad Rodach, Jerman  melalui BeBee Deutschland
# 785738                             Malaysia           melalui Ricebowl
# 785739  Newark, New Jersey, Amerika Serikat        melalui Recruit.net
# 785740                                India             melalui Trigyn
#
#        job_schedule_type  job_work_from_home search_location  \
# 785736   Pekerjaan tetap               False       Singapore
# 785737   Pekerjaan tetap               False         Germany
# 785738   Pekerjaan tetap               False        Malaysia
# 785739   Pekerjaan tetap               False           Sudan
# 785740   Pekerjaan tetap               False           India
#
#            job_posted_date  job_no_degree_mention  job_health_insurance  \
# 785736 2023-03-13 06:16:16                  False                 False
# 785737 2023-03-12 06:18:18                  False                 False
# 785738 2023-03-12 06:32:36                  False                 False
# 785739 2023-03-12 06:32:15                  False                 False
# 785740 2023-03-13 06:16:31                  False                 False
#
#        job_country salary_rate  salary_year_avg  salary_hour_avg  \
# 785736   Singapore        None              NaN              NaN
# 785737     Germany        None              NaN              NaN
# 785738    Malaysia        None              NaN              NaN
# 785739       Sudan        None              NaN              NaN
# 785740       India        None              NaN              NaN
#
#                               company_name  \
# 785736  CAREERSTAR INTERNATIONAL PTE. LTD.
# 785737                    HABA FAMILYGROUP
# 785738               Lendlease Corporation
# 785739                         Capital One
# 785740                              Trigyn
#
#                                                job_skills  \
# 785736  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 785737                     ['sas', 'sas', 'sql', 'excel']
# 785738                            ['powerpoint', 'excel']
# 785739  ['python', 'go', 'nosql', 'sql', 'mongo', 'she...
# 785740                                    ['aws', 'flow']
#
#                                           job_type_skills
# 785736  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 785737  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 785738         {'analyst_tools': ['powerpoint', 'excel']}
# 785739  {'cloud': ['aws', 'snowflake', 'azure', 'redsh...
# 785740              {'cloud': ['aws'], 'other': ['flow']}

# %%
df.sample(10)
# Out:
#               job_title_short  \
# 93700          Data Scientist
# 404442         Data Scientist
# 580355           Data Analyst
# 112940         Data Scientist
# 770137          Data Engineer
# 745723           Data Analyst
# 123787           Data Analyst
# 759783         Data Scientist
# 153015           Data Analyst
# 775279  Senior Data Scientist
#
#                                                 job_title  \
# 93700                                      Data Scientist
# 404442  Business Intelligence (BI) Report and Analytic...
# 580355                                       data analyst
# 112940            Digital Business Data Scientist (w/m/d)
# 770137          Data Engineer, Scala Experience is a MUST
# 745723                                       Data Analyst
# 123787                                Junior Data Analyst
# 759783                                    Data Scientists
# 153015                               Data Analyst (Entry)
# 775279                 Data & Analytics Delivery Director
#
#                                              job_location             job_via  \
# 93700                        Dubai - United Arab Emirates   via Jobrapido.com
# 404442                                     Sacramento, CA        via LinkedIn
# 580355                                    Machakos, Kenya     via Trabajo.org
# 112940  Bolzano, Autonomous Province of Bolzano – Sout...        via Sercanto
# 770137                                         Irvine, CA        via LinkedIn
# 745723  Kuala Lumpur, Federal Territory of Kuala Lumpu...  via BeBee Malaysia
# 123787                            Cape Town, South Africa            via Pnet
# 759783                                      Canutillo, TX        via LinkedIn
# 153015                                      St. Louis, MO        via Snagajob
# 775279                                      Paris, France           via BeBee
#
#                job_schedule_type  job_work_from_home  \
# 93700                  Full-time               False
# 404442  Full-time and Contractor               False
# 580355                 Full-time               False
# 112940                 Full-time               False
# 770137                 Full-time               False
# 745723                 Full-time               False
# 123787                 Full-time               False
# 759783                 Full-time               False
# 153015                 Full-time               False
# 775279                 Full-time               False
#
#                   search_location     job_posted_date  job_no_degree_mention  \
# 93700        United Arab Emirates 2023-07-26 00:27:10                  False
# 404442  California, United States 2023-12-14 18:01:02                   True
# 580355                      Kenya 2023-01-18 09:32:02                   True
# 112940                      Italy 2023-01-31 00:29:27                  False
# 770137     Florida, United States 2023-05-01 01:14:44                  False
# 745723                   Malaysia 2023-07-25 20:14:12                  False
# 123787               South Africa 2023-09-27 08:23:27                  False
# 759783                      Sudan 2023-10-31 20:54:39                  False
# 153015    Illinois, United States 2023-05-07 08:01:42                  False
# 775279                     France 2023-08-13 01:20:45                   True
#
#         job_health_insurance           job_country salary_rate  \
# 93700                  False  United Arab Emirates        None
# 404442                 False         United States       month
# 580355                 False                 Kenya        None
# 112940                 False                 Italy        None
# 770137                 False         United States        None
# 745723                 False              Malaysia        None
# 123787                 False          South Africa        None
# 759783                 False                 Sudan        None
# 153015                 False         United States        None
# 775279                 False                France        None
#
#         salary_year_avg  salary_hour_avg                    company_name  \
# 93700               NaN              NaN                    dnata Travel
# 404442              NaN              NaN  California Franchise Tax Board
# 580355              NaN              NaN             beBee Professionals
# 112940              NaN              NaN                         Loacker
# 770137              NaN              NaN                     CyberCoders
# 745723              NaN              NaN                Oxydata Software
# 123787              NaN              NaN                      Network IT
# 759783              NaN              NaN                          Upwork
# 153015              NaN              NaN                 The Judge Group
# 775279              NaN              NaN                            Epam
#
#                                                job_skills  \
# 93700                              ['sql', 'r', 'python']
# 404442  ['c', 'python', 'sql', 'sas', 'sas', 'db2', 'j...
# 580355                                               None
# 112940                                          ['excel']
# 770137  ['scala', 'mongodb', 'mongodb', 'nosql', 'java...
# 745723  ['python', 'sql', 'azure', 'databricks', 'pysp...
# 123787      ['python', 'r', 'sql', 'tableau', 'power bi']
# 759783                                  ['sql', 'python']
# 153015                                               None
# 775279                                               None
#
#                                           job_type_skills
# 93700             {'programming': ['sql', 'r', 'python']}
# 404442  {'analyst_tools': ['sas', 'outlook', 'word', '...
# 580355                                               None
# 112940                       {'analyst_tools': ['excel']}
# 770137  {'analyst_tools': ['word'], 'cloud': ['redshif...
# 745723  {'cloud': ['azure', 'databricks'], 'libraries'...
# 123787  {'analyst_tools': ['tableau', 'power bi'], 'pr...
# 759783                 {'programming': ['sql', 'python']}
# 153015                                               None
# 775279                                               None

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original

# %%
df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# 5   NaN
# Name: salary_year_avg, dtype: float64

# %%
median_salary = df_altered['salary_year_avg'].median()

median_salary
# Out:
# 115000.0

# %%
df_altered['salary_year_avg'] = df_altered['salary_year_avg'].fillna(median_salary)

df_altered.loc[:5, 'salary_year_avg']
# Out:
# 0    115000.0
# 1    115000.0
# 2    115000.0
# 3    115000.0
# 4    115000.0
# 5    115000.0
# Name: salary_year_avg, dtype: float64

# %%
id(df_original)
# Out:
# 1527424281616

# %%
id(df_altered)
# Out:
# 1527424281616

# %%
id(df_altered) == id(df_original)
# Out:
# True

# %%
dataset = load_dataset('lukebarousse/data_jobs')
df_original = dataset['train'].to_pandas()

# %%
df_altered = df_original.copy()

# %%
print('ID of original DataFrame:', id(df_original))
print('ID of altered DataFrame:', id(df_altered))
print('Are the IDs the same?', id(df_altered) == id(df_original))
# Out:
# ID of original DataFrame: 1527163474064
# ID of altered DataFrame: 1527163474384
# Are the IDs the same? False
